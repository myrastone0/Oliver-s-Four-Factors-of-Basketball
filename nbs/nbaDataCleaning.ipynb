# %%
import pandas as pd
import numpy as np

# %%
year = '2019'
df = pd.read_csv('../data/nba_team_box_scores_'+str(year)+'.csv')

# %%
df.describe()
# Out:
#         Unnamed: 0        gameID      teamPTS      teamFG%     team3PT%  \
# count  2458.000000  2.458000e+03  2458.000000  2458.000000  2458.000000
# mean   1228.500000  4.010713e+08   111.195688    46.143124    35.520342
# std     709.707804  3.712529e+02    12.648481     5.333076     8.682060
# min       0.000000  4.010702e+08    68.000000    27.800000    11.500000
# 25%     614.250000  4.010710e+08   103.000000    42.600000    29.600000
# 50%    1228.500000  4.010713e+08   111.000000    46.000000    35.300000
# 75%    1842.750000  4.010716e+08   119.000000    49.500000    40.900000
# max    2457.000000  4.010719e+08   168.000000    64.900000    84.200000
#
#            teamFT%     teamTREB     teamASST      teamSTL      teamBLK  ...  \
# count  2458.000000  2458.000000  2458.000000  2458.000000  2458.000000  ...
# mean     76.712449    53.513832    24.583401     7.633035     4.951587  ...
# std      10.237144     7.451704     5.119945     2.947996     2.485877  ...
# ...
